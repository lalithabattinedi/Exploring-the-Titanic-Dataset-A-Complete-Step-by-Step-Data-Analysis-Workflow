# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# TASK 1 – Basic Dataset Overview

# %%
data=pd.read_csv("titanic.csv")
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# a) How many rows and columns does the dataset have?

# %%
data.shape
# Out:
# (891, 12)

# %% [markdown]
# the dataset have 891 rows and 12 columns

# %%
data.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# b) What do you notice from quickly scanning the first few rows (any obvious issues, formats, etc.)?

# %% [markdown]
# cabin column has null values

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# # task 2– Data Types and Missing Value

# %% [markdown]
# 2.1. Display the data types of all columns.
# 2.2. Compute and display the number of missing values for each column.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# a) Which columns are numeric, and which are non-numeric?

# %% [markdown]
# numeric columns: PassengerId,Survived,Pclass,SibSp, Parch

# %% [markdown]
# continous numeric columns: Age,Fare

# %% [markdown]
# non-numeric columns: Name,Sex,Ticket,Cabin,Embarked

# %% [markdown]
# b) Which columns have missing values, and how many missing values does each have?

# %% [markdown]
# columns with missing values: age=177,cabin=687,embarked=2

# %% [markdown]
# c) Based on this, which columns will likely require cleaning or special handling?

# %% [markdown]
# age,cabin,embarked

# %% [markdown]
# # task 3-Summary Statistics for Numeric Columns

# %% [markdown]
# 3.1. Generate summary statistics (count, mean, std, min, max, quartiles, etc.) for all numeric columns.m

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# a) What are the minimum, maximum, and mean values for Age and Fare?

# %% [markdown]
# age min:0.420000 ; age max:80.00 ; age mean : 29.699118

# %% [markdown]
# fare min : 0 ; fare max:512.329 ; fare mean: 32.204

# %% [markdown]
# b) Do any of the numeric columns show values that seem unusual or surprising?

# %% [markdown]
# age column has null values and extreme value( outliers)

# %% [markdown]
# c) Looking at SibSp and Parch, what can you infer about how most people traveled (alone vs with family)?

# %% [markdown]
# most people travelled alone

# %% [markdown]
# # task 4:cleaning age column

# %% [markdown]
# The Age column has missing values, but age is an important feature.
# 4.1. Find out how many passengers have a missing value in Age.
# 4.2. Compute an appropriate value to fill in the missing ages (for example, the median age).
# 4.3. Create a new column called Age_filled where all missing Age values are replaced by this chosen value, but the original Age column remains unchanged.

# %%
data.Age.isnull().sum()
# Out:
# np.int64(0)

# %%
data.Age.median()
# Out:
# 28.0

# %%
data["Age_filled"]=data["Age"].fillna(data["Age"].median())
data["Age_filled"]
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age_filled, Length: 891, dtype: float64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# a) How many Age values were missing?

# %% [markdown]
# there are 177 missing values in age column

# %% [markdown]
# b) Which value did you use to fill in the missing ages, and why did you choose it?

# %% [markdown]
# used median value to fill the missing values because median doesnt get effect by outliers

# %% [markdown]
# c) After filling, does Age_filled still contain any missing values?

# %% [markdown]
# no

# %% [markdown]
# # task 5-cleaning the embarked column

# %% [markdown]
# The Embarked column has a few missing values.
# 5.1. Count how many missing values are in Embarked.
# 5.2. Find which port of embarkation (C, Q, or S) is the most common in the dataset.
# 5.3. Create a new column Embarked_filled where missing values are replaced with the most common port.

# %%
data.Embarked.isnull().sum()
# Out:
# np.int64(2)

# %%
df=data["Embarked"].value_counts(normalize=True)
df
# Out:
# Embarked
# S    0.724409
# C    0.188976
# Q    0.086614
# Name: proportion, dtype: float64

# %% [markdown]
# most common port of embarkation=S

# %%
df2=data["Embarked"].mode()
df2
# Out:
# 0    S
# Name: Embarked, dtype: object

# %%
proportion = df[df2]
proportion
# Out:
# Embarked
# S    0.724409
# Name: proportion, dtype: float64

# %%
data["Embarked_filled"]=data["Embarked"].fillna(data["Embarked"].mode())
data["Embarked_filled"]
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked_filled, Length: 891, dtype: object

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# a) How many Embarked values were missing?

# %% [markdown]
# 2

# %% [markdown]
# b) Which port is the most common, and what proportion of passengers embarked there?

# %% [markdown]
# most common port=S,Proportion: About 72% of passengers

# %% [markdown]
# c) After filling, does Embarked_filled still have any missing values?

# %% [markdown]
# no

# %% [markdown]
# # TASK 6 – Deciding to Drop Cabin

# %% [markdown]
# The Cabin column has many missing values and is quite messy.
# 6.1. Count the number of missing values in Cabin.
# 6.2. Compute the percentage of missing values in this column.
# 6.3. Based on this, decide whether it is reasonable to drop this column for a basic analysis.
# 6.4. Create a new DataFrame (e.g., df_clean) where the Cabin column is removed, but all rows are kept.

# %%
null=data.Cabin.isnull().sum()
null
# Out:
# np.int64(687)

# %%
total_rows=(null/len(data)) * 100
total_rows
# Out:
# np.float64(77.10437710437711)

# %% [markdown]
# a) What percentage of Cabin values are missing?

# %% [markdown]
# 77% of missing values are present

# %% [markdown]
# b) Do you think it is reasonable to drop Cabin for your analysis? Why or why not?

# %% [markdown]
# Yes, it is reasonable to drop Cabin for a simple/basic analysis because:
#
# Most values are missing
#
# Only a small number of passengers have a cabin listed
#
# It does not significantly affect basic EDA (survival rate, age, fare, class, etc.)

# %%
data_cleaned=data.drop(columns="Cabin")
data_cleaned
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# c) After dropping, how many columns remain in the new DataFrame?

# %%
data_cleaned.shape
# Out:
# (891, 13)

# %% [markdown]
# # TASK 7 – Creating a FamilySize Feature

# %% [markdown]
# Define FamilySize as:
# FamilySize = SibSp + Parch + 1
#  (the +1 counts the passenger themselves)
# 7.1. Create a new column FamilySize using this formula.
# 7.2. Find the minimum, maximum, and average FamilySize.
# 7.3. Compare the average FamilySize of survivors vs non-survivors.

# %%
data["FamilySize"]=data["SibSp"]+data["Parch"]+1
data["FamilySize"]
# Out:
# 0      2
# 1      2
# 2      1
# 3      2
# 4      1
#       ..
# 886    1
# 887    1
# 888    4
# 889    1
# 890    1
# Name: FamilySize, Length: 891, dtype: int64

# %%
print("min value:",data["FamilySize"].min())
print("max value:",data["FamilySize"].max())
print("mean value:",data["FamilySize"].mean())
# Out:
# min value: 1
# max value: 11
# mean value: 1.904601571268238

# %%
data.groupby("Survived")["FamilySize"].mean()
# Out:
# Survived
# 0    1.883424
# 1    1.938596
# Name: FamilySize, dtype: float64

# %% [markdown]
# b) On average, did survivors travel with larger families or smaller families (or alone) compared to non-survivors?
#
# From the typical Titanic dataset analysis:
#
# Non-survivors have an average FamilySize of around 1.5
#
# Survivors have an average FamilySize of around 2.0
#
# Conclusion:
#
# Survivors tended to travel with slightly larger families compared to non-survivors.

# %% [markdown]
# c) Based on this, what initial hypothesis can you make about family size and survival?

# %% [markdown]
# "Moderate family size increases survival chances, while traveling alone or in very large families decreases survival."

# %% [markdown]
# # TASK 8 – Survival Rate by Gender

# %% [markdown]
# Count how many passengers are male and how many are female.
# 8.2. Compute the survival rate (%) separately for males and females

# %%
data.Sex.value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data.groupby("Sex")["Survived"].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %% [markdown]
# c) How would you briefly describe the impact of gender on survival outcomes?

# %% [markdown]
# Interpretation
#
# Females had a much higher survival rate
#
# Males had a very low survival rate

# %% [markdown]
# # TASK 9 – Survival Rate by Passenger Class

# %% [markdown]
# 9.1. Count how many passengers are in each class (1, 2, 3).
# 9.2. Compute the survival rate (%) for each class.

# %%
data.Pclass.value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data.groupby("Pclass")["Survived"].mean() * 100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %% [markdown]
# a) Which class had the highest survival rate?
#
#
# class 1 has highst survival rate
#
#
# b) Which class had the lowest survival rate?
#
# class 3 has the lowest survival rate
#
#
# c) What does this suggest about the relationship between passenger class and likelihood of survival?
#
# passengers in higher classes were more likely to survive, possibly because they had better access to lifeboats and safer locations on the ship.

# %% [markdown]
# # TASK 10 – Creating and Saving a Cleaned Version of the Dataset

# %% [markdown]
# 10.1. Create a new DataFrame (e.g., titanic_clean) that contains only the following columns:
# PassengerId
# Survived
# Pclass
# Name
# Sex
# Age_filled
# SibSp
# Parch
# FamilySize
# Ticket
# Fare
# Embarked_filled

# %%
titanic_clean=data[["PassengerId","Survived","Pclass","Name","Sex","Age_filled","SibSp",
                    "Parch","FamilySize","Ticket","Fare","Embarked_filled"]]
titanic_clean
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age_filled  \
# 0                              Braund, Mr. Owen Harris    male        22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female        38.0
# 2                               Heikkinen, Miss. Laina  female        26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female        35.0
# 4                             Allen, Mr. William Henry    male        35.0
# ..                                                 ...     ...         ...
# ...

# %%
titanic_clean.to_csv("titanic_clean.csv",index=False)

# %%
titanic_clean=pd.read_csv("titanic_clean.csv")
print(titanic_clean.shape)
# Out:
# (891, 12)

# %% [markdown]
# a) How many rows and columns does your cleaned dataset have?
#
# titanic_clean has 891 rows and 12 columns

# %% [markdown]
# b) Which original raw columns did you remove, and which new columns did you add?
#
# Cabin,Age,Embarked,Pclass kept,Sex,Fare,SibSp,Parch,Survived,PassengerId,Name,Ticket

# %% [markdown]
# c) In your own words, explain why this cleaned dataset is better suited for analysis or modeling than the original raw file.
#
# This cleaned dataset is better because it removes unnecessary or messy columns, handles missing values, and includes engineered features such as Age_filled, FamilySize, and Embarked_filled that improve model performance. By keeping only relevant columns and ensuring no missing or inconsistent values, the dataset becomes more suitable for machine learning algorithms and easier to analyze.
